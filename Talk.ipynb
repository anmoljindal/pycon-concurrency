# %% [markdown]
# # Concurrency Patterns in Python

# %% [markdown]
# ## Operations
#
# 1. CPU Bound Operations
#     - eg: calculations, data processing
# 2. I/O Bound Operations
#     - eg: http requests, disk read operations

# %% [markdown]
# ## Threads
#
# Threads are a seperate flow of execution.

# %%
import threading
import time

def thread_function(name):
    time.sleep(2)
    print('Thread completed execution',threading.get_ident())

# %%
import dis

dis.dis(thread_function)
# Out:
#   5           0 LOAD_GLOBAL              0 (time)
#               2 LOAD_ATTR                1 (sleep)
#               4 LOAD_CONST               1 (2)
#               6 CALL_FUNCTION            1
#               8 POP_TOP
#
#   6          10 LOAD_GLOBAL              2 (print)
#              12 LOAD_CONST               2 ('Thread completed execution')
#              14 LOAD_GLOBAL              3 (threading)
#              16 LOAD_ATTR                4 (get_ident)
#              18 CALL_FUNCTION            0
#              20 CALL_FUNCTION            2
#              22 POP_TOP
#              24 LOAD_CONST               0 (None)
#              26 RETURN_VALUE

# %% [markdown]
# ### starting a single thread

# %%
x = threading.Thread(target=thread_function, args=(1,),daemon=False)
x.start()
# x.join()

print(x.is_alive())
print('hi')
# Out:
# True
# hi
# Thread completed execution 140010548352768

# %% [markdown]
# ### starting multiple threads

# %%
threads = []
for i in range(3):
    x = threading.Thread(target=thread_function, args=(1,))
    x.start()
    threads.append(x)

for x in threads:
    x.join()
# Out:
# Thread completed execution 140010548352768
# Thread completed execution 140010565138176
# Thread completed execution 140010556745472

# %% [markdown]
# ### using thread pool executor

# %%
import concurrent.futures

with concurrent.futures.ThreadPoolExecutor(max_workers=3) as executor:
        executor.map(thread_function, range(3))
# Out:
# Thread completed execution 140010556745472
# Thread completed execution 140010565138176
# Thread completed execution 140010548352768

# %% [markdown]
# ## Race Conditions

# %%
class FakeDatabase:
    def __init__(self):
        self.value = 0

    def update(self, name):
        local_copy = self.value
        local_copy += 1
        time.sleep(0.1)
        self.value = local_copy

# %%
database = FakeDatabase()
with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
    for index in range(10):
        executor.submit(database.update, index)

database.value
# Out:
# 10

# %% [markdown]
# ## Locks
#
# a lock or mutex (from mutual exclusion) is a synchronization mechanism for enforcing limits on access to a resource in an environment where there are many threads of execution

# %%
class FakeDatabase:
    def __init__(self):
        self.value = 0
        self._lock = threading.Lock()

    def update(self, name):
        with self._lock:
            local_copy = self.value
            local_copy += 1
            time.sleep(0.1)
            self.value = local_copy

# %%
l = threading.Lock()
print("before first acquire")
l.acquire()
print("before second acquire")
l.acquire()
print("acquired lock twice")
# Out:
# before first acquire
# before second acquire
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-258068ea8ea4> in <module>
#       3 l.acquire()
#       4 print("before second acquire")
# ----> 5 l.acquire()
#       6 print("acquired lock twice")
#
# KeyboardInterrupt:

# %% [markdown]
# ### RLock
#
# can be aquired and released multiple times

# %% [markdown]
# #### Example 1: scrape websites

# %%
##syncronous version

import requests
import time


def download_site(url, session):
    with session.get(url) as response:
        pass #do something


def download_all_sites(sites):
    with requests.Session() as session:
        for url in sites:
            download_site(url, session)

sites = [
    "https://www.jython.org",
    "http://olympus.realpython.org/dice",
] * 80
start_time = time.time()
download_all_sites(sites)
duration = time.time() - start_time
print(f"Downloaded {len(sites)} in {duration} seconds")
# Out:
# Downloaded 160 in 38.64874482154846 seconds

# %%
##threading version

import concurrent.futures
import requests
import threading
import time


thread_local = threading.local()

variable_list = []

def get_session():
    if not hasattr(thread_local, "session"):
        thread_local.session = requests.Session()
    return thread_local.session


def download_site(url):
    session = get_session()
    with session.get(url) as response:
        variable_list.append(url)
#         pass #do something


def download_all_sites(sites):
    with concurrent.futures.ThreadPoolExecutor(max_workers=160) as executor:
        executor.map(download_site, sites)

sites = [
    "https://www.jython.org",
    "http://olympus.realpython.org/dice",
] * 80
start_time = time.time()
download_all_sites(sites)
duration = time.time() - start_time
print(f"Downloaded {len(sites)} in {duration} seconds")
print(len(variable_list))
# Out:
# Downloaded 160 in 2.54917049407959 seconds
# 160

# %% [markdown]
# ## Forms of multitasking
#
# 1. Pre-emptive multitasking
#     - switches threads at interval of 1000 bytecodes. In Python 3 the GIL’s implementation is more complex, and the check interval is not a fixed number of bytecodes but 15 milliseconds.
#
# 2. Cooperative multitasking
#     - tasks define when they are finished

# %% [markdown]
# ### Asyncio
#
# **levels of abstraction**
#
# 1. futures
# 2. coroutines
# 3. Tasks
#
# **Special Keywords**
#
# - async
# - await

# %%
import sys
# !{sys.executable} -m pip install asyncio
# !{sys.executable} -m pip install aiohttp
# !{sys.executable} -m pip install nest_asyncio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nest_asyncio in /home/anmol/.local/lib/python3.6/site-packages (1.4.0)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import asyncio
import time
import aiohttp

async def download_site(session, url):
    async with session.get(url) as response:
        pass #do something


async def download_all_sites(sites):
    async with aiohttp.ClientSession() as session:
        tasks = []
        for url in sites:
            task = asyncio.ensure_future(download_site(session, url))
            tasks.append(task)
        await asyncio.gather(*tasks, return_exceptions=True)

if __name__ == '__main__': 
    sites = [
        "https://www.jython.org",
        "http://olympus.realpython.org/dice",
    ] * 80
    start_time = time.time()
    asyncio.get_event_loop().run_until_complete(download_all_sites(sites))
#     asyncio.run(download_all_sites(sites))
    duration = time.time() - start_time
    print(f"Downloaded {len(sites)} sites in {duration} seconds")
# Out:
# Downloaded 160 sites in 2.0065319538116455 seconds

# %%
import requests
import multiprocessing
import time

session = None

def set_global_session():
    global session
    if not session:
        session = requests.Session()


def download_site(url):
    with session.get(url) as response:
        name = multiprocessing.current_process().name
        pass #do something


def download_all_sites(sites):
    with multiprocessing.Pool(20, initializer=set_global_session) as pool:
        pool.map(download_site, sites)

sites = [
    "https://www.jython.org",
    "http://olympus.realpython.org/dice",
] * 80
start_time = time.time()
download_all_sites(sites)
duration = time.time() - start_time
print(f"Downloaded {len(sites)} in {duration} seconds")
# Out:
# Downloaded 160 in 2.94077467918396 seconds

# %% [markdown]
# ### Message Passing between threads

# %%
import concurrent.futures
import queue
import random
import threading
import time

def producer(queue, event):
    """Pretend we're getting a number from the network."""
    while not event.is_set():
        message = random.randint(1, 101)
        print("Producer got message: ", message)
        queue.put(message)

def consumer(queue, event):
    """Pretend we're saving a number in the database."""
    while not event.is_set() or not queue.empty():
        message = queue.get()
        print("Consumer storing message: {} (size={})".format(message, queue.qsize()))

pipeline = queue.Queue(maxsize=10)
event = threading.Event()
with concurrent.futures.ThreadPoolExecutor(max_workers=2) as executor:
    executor.submit(producer, pipeline, event)
    executor.submit(consumer, pipeline, event)

    time.sleep(0.1)
    event.set()
# Out:
# Producer got message:  41
# Producer got message:  87
# Producer got message:  50
# Producer got message:  81
# Producer got message:  25
# Producer got message:  20
# Producer got message:  51
# Producer got message:  16
# Producer got message:  8
# Producer got message:  17
# Producer got message:  101
# Consumer storing message: 41 (size=9)
# Producer got message: Consumer storing message: 87 (size=9) 47
# Producer got message:  57
#
# Consumer storing message: 50 (size=9)
# Consumer storing message: 81 (size=8)
# Consumer storing message: 25 (size=7)
# Consumer storing message: 20 (size=6)
# Consumer storing message: 51 (size=5)
# Consumer storing message: 16 (size=4)
# Consumer storing message: 8 (size=3)
# Consumer storing message: 17 (size=2)
# Consumer storing message: 101 (size=1)
# Consumer storing message: 47 (size=0)
# Producer got message:  Consumer storing message: 57 (size=0)96
# Producer got message:  20
# Producer got message:  8
# Producer got message:  41
# Producer got message:  80
# Producer got message:  26
# Producer got message:  71
# Producer got message:  1
# Producer got message:  98
# Producer got message:  45
# Producer got message:  43
#
# Consumer storing message: 96 (size=9)Producer got message:
# Consumer storing message: 20 (size=9)
# Consumer storing message: 8 (size=8)
# Consumer storing message: 41 (size=7)
# Consumer storing message: 80 (size=6)
# Consumer storing message: 26 (size=5)
# Consumer storing message: 71 (size=4)
# Consumer storing message: 1 (size=3)
# Consumer storing message: 98 (size=2)
# Consumer storing message: 45 (size=1)
# Consumer storing message: 43 (size=0)
#  36
# Producer got message:  24
# Producer got message:  25
# Producer got message:  28
# Producer got message:  21
# Producer got message:  3
# Producer got message:  49
# Producer got message:  4
# Producer got message:  99
# Producer got message:  95
# Producer got message:  19
# Consumer storing message: 36 (size=9)Producer got message:
# Consumer storing message: 24 (size=9)
# Consumer storing message: 25 (size=8)
# Consumer storing message: 28 (size=7)
# Consumer storing message: 21 (size=6)
# Consumer storing message: 3 (size=5)
# Consumer storing message: 49 (size=4)
# Consumer storing message: 4 (size=3)
# Consumer storing message: 99 (size=2)
# Consumer storing message: 95 (size=1)
# Consumer storing message: 19 (size=0)
#  8
# Producer got message:  55
# Producer got message:  27
# Consumer storing message: 8 (size=1)Producer got message:  47
# Producer got message:  53
# Producer got message:  41
# Producer got message:  36
# Producer got message:  87
# Producer got message:  6
# Producer got message:  69
# Producer got message:  25
# Producer got message:  64
#
# Consumer storing message: 55 (size=9)
# Consumer storing message: 27 (size=8)
# Consumer storing message: 47 (size=7)
# Consumer storing message: 53 (size=6)
# Consumer storing message: 41 (size=5)
# Consumer storing message: 36 (size=4)
# Consumer storing message: 87 (size=3)
# Consumer storing message: 6 (size=2)
# Consumer storing message: 69 (size=1)
# Consumer storing message: 25 (size=0)
# Producer got message: Consumer storing message: 64 (size=0)
#  19
# Producer got message:  26
# Producer got message:  39
# Producer got message:  15
# Producer got message:  53
# Producer got message:  94
# Producer got message:  71
# Producer got message:  63
# Producer got message:  89
# Producer got message:  85
# Producer got message:  27
# Consumer storing message: 19 (size=9)
# Consumer storing message: 26 (size=8)
# Consumer storing message: 39 (size=7)
# Consumer storing message: 15 (size=6)
# Consumer storing message: 53 (size=5)
# Consumer storing message: 94 (size=4)
# Consumer storing message: 71 (size=3)
# Consumer storing message: 63 (size=2)
# Consumer storing message: 89 (size=1)
# Consumer storing message: 85 (size=0)
# Producer got message:  98
# Producer got message:  7
# Producer got message:  27
# Producer got message:  51
# Producer got message:  91
# Producer got message:  96
# Producer got message:  45
# Producer got message:  52
# Producer got message:  95
# Producer got message:  39
# Consumer storing message: 27 (size=9)
# Consumer storing message: 98 (size=8)
# Consumer storing message: 7 (size=7)
# Consumer storing message: 27 (size=6)
# Consumer storing message: 51 (size=5)
# Consumer storing message: 91 (size=4)
# Consumer storing message: 96 (size=3)
# Consumer storing message: 45 (size=2)
# Consumer storing message: 52 (size=1)
# Consumer storing message: 95 (size=0)
# Producer got message:  91
# Producer got message:  26
# Producer got message:  60
# Producer got message:  15
# Producer got message:  49
# Producer got message:  28
# Producer got message:  58
# Producer got message:  64
# Producer got message:  71
# Producer got message:  75
# Consumer storing message: 39 (size=9)
# Consumer storing message: 91 (size=8)
# Consumer storing message: 26 (size=7)
# Consumer storing message: 60 (size=6)
# Consumer storing message: 15 (size=5)
# Consumer storing message: 49 (size=4)
# Consumer storing message: 28 (size=3)
# Consumer storing message: 58 (size=2)
# Consumer storing message: 64 (size=1)
# Consumer storing message: 71 (size=0)
# Producer got message:  1
# Producer got message:  44
# Producer got message:  70
# Producer got message:  34
# Producer got message:  73
# Producer got message:  58
# Producer got message:  84
# Producer got message:  97
# Producer got message:  85
# Producer got message:  4
# Consumer storing message: 75 (size=9)
# Consumer storing message: 1 (size=8)
# Consumer storing message: 44 (size=7)
# Consumer storing message: 70 (size=6)
# Consumer storing message: 34 (size=5)
# Consumer storing message: 73 (size=4)
# Consumer storing message: 58 (size=3)
# Consumer storing message: 84 (size=2)
# Consumer storing message: 97 (size=1)
# Consumer storing message: 85 (size=0)
# Producer got message:  4
# Producer got message:  55
# Producer got message:  56
# Producer got message:  66
# Producer got message:  88
# Producer got message:  34
# Producer got message:  44
# Producer got message:  92
# Producer got message:  32
# Producer got message:  72
# Consumer storing message: 4 (size=9)
# Consumer storing message: 4 (size=8)
# Consumer storing message: 55 (size=7)
# Consumer storing message: 56 (size=6)
# Consumer storing message: 66 (size=5)
# Consumer storing message: 88 (size=4)
# Consumer storing message: 34 (size=3)
# Consumer storing message: 44 (size=2)
# Consumer storing message: 92 (size=1)
# Consumer storing message: 32 (size=0)
# Producer got message:  21
# Producer got message:  82
# Producer got message:  40
# Producer got message:  61
# Producer got message:  100
# Producer got message:  30
# Producer got message:  28
# Producer got message:  1
# Producer got message:  47
# Producer got message:  80
# Consumer storing message: 72 (size=9)
# Consumer storing message: 21 (size=8)
# Consumer storing message: 82 (size=7)
# Consumer storing message: 40 (size=6)
# Consumer storing message: 61 (size=5)
# Consumer storing message: 100 (size=4)
# Consumer storing message: 30 (size=3)
# Consumer storing message: 28 (size=2)
# Consumer storing message: 1 (size=1)
# Consumer storing message: 47 (size=0)
# Producer got message:  63
# Producer got message:  81
# Producer got message:  9
# Producer got message:  55
# Producer got message:  94
# Producer got message:  42
# Producer got message:  34
# Producer got message:  86
# Producer got message:  89
# Producer got message:  3
# Consumer storing message: 80 (size=9)
# Consumer storing message: 63 (size=8)
# Consumer storing message: 81 (size=7)
# Consumer storing message: 9 (size=6)
# Consumer storing message: 55 (size=5)
# Consumer storing message: 94 (size=4)
# Consumer storing message: 42 (size=3)
# Consumer storing message: 34 (size=2)
# Consumer storing message: 86 (size=1)
# Consumer storing message: 89 (size=0)
# Producer got message:  6
# Producer got message:  44
# Producer got message:  49
# Producer got message:  17
# Producer got message:  25
# Producer got message:  48
# Producer got message:  99
# Consumer storing message: 3 (size=6)
# Consumer storing message: 6 (size=5)
# Consumer storing message: 44 (size=4)
# Consumer storing message: 49 (size=3)
# Consumer storing message: 17 (size=2)
# Consumer storing message: 25 (size=1)
# Consumer storing message: 48 (size=0)
# Producer got message:  69
# Producer got message:  80
# Producer got message:  4
# Producer got message:  58
# Producer got message:  10
# Producer got message:  28
# Producer got message:  67
# Producer got message:  87
# Producer got message:  54
# Producer got message:  75
# Consumer storing message: 99 (size=9)
# Consumer storing message: 69 (size=8)
# Consumer storing message: 80 (size=7)
# Consumer storing message: 4 (size=6)
# Consumer storing message: 58 (size=5)
# Consumer storing message: 10 (size=4)
# Consumer storing message: 28 (size=3)
# Consumer storing message: 67 (size=2)
# Consumer storing message: 87 (size=1)
# Consumer storing message: 54 (size=0)
# Producer got message:  98
# Producer got message:  18
# Producer got message:  79
# Producer got message:  51
# Producer got message:  27
# Producer got message:  29
# Producer got message:  18
# Producer got message:  96
# Producer got message:  92
# Producer got message:  92
# Consumer storing message: 75 (size=9)
# Consumer storing message: 98 (size=8)
# Consumer storing message: 18 (size=7)
# Consumer storing message: 79 (size=6)
# Consumer storing message: 51 (size=5)
# Consumer storing message: 27 (size=4)
# Consumer storing message: 29 (size=3)
# Consumer storing message: 18 (size=2)
# Consumer storing message: 96 (size=1)
# Consumer storing message: 92 (size=0)
# Producer got message:  20
# Producer got message:  38
# Producer got message:  26
# Producer got message:  95
# Producer got message:  55
# Producer got message:  83
# Producer got message:  42
# Producer got message:  95
# Producer got message:  64
# Producer got message:  42
# Consumer storing message: 92 (size=9)
# Consumer storing message: 20 (size=8)
# Consumer storing message: 38 (size=7)
# Consumer storing message: 26 (size=6)
# Consumer storing message: 95 (size=5)
# Consumer storing message: 55 (size=4)
# Consumer storing message: 83 (size=3)
# Consumer storing message: 42 (size=2)
# Consumer storing message: 95 (size=1)
# Consumer storing message: 64 (size=0)
# Producer got message:  90
# Producer got message:  82
# Producer got message:  24
# Producer got message:  84
# Producer got message:  23
# Producer got message:  41
# Producer got message:  16
# Producer got message:  41
# Producer got message:  31
# Producer got message:  97
# Consumer storing message: 42 (size=9)
# Consumer storing message: 90 (size=8)
# Consumer storing message: 82 (size=7)
# Consumer storing message: 24 (size=6)
# Consumer storing message: 84 (size=5)
# Consumer storing message: 23 (size=4)
# Consumer storing message: 41 (size=3)
# Consumer storing message: 16 (size=2)
# Consumer storing message: 41 (size=1)
# Consumer storing message: 31 (size=0)
# Producer got message:  98
# Producer got message:  29
# Producer got message:  88
# Consumer storing message: 97 (size=2)
# Consumer storing message: 98 (size=1)
# Consumer storing message: 29 (size=0)
# Producer got message: Consumer storing message: 88 (size=0) 59
# Producer got message:  95
# Producer got message:  87
# Producer got message:  92
# Producer got message:  58
# Producer got message:  50
# Producer got message:  66
# Producer got message:  36
# Producer got message:  63
# Producer got message:  16
# Consumer storing message: 59 (size=8)
# Consumer storing message: 95 (size=7)
#
# Consumer storing message: 87 (size=6)
# Consumer storing message: 92 (size=5)Producer got message:  35
# Producer got message:  36
# Consumer storing message: 58 (size=6)
# Consumer storing message: 50 (size=5)
# Producer got message:  60
# Producer got message:  84
# Producer got message:  32
# Producer got message:  58
# Producer got message:  64
#
# Consumer storing message: 66 (size=9)Producer got message:
# 4
# Consumer storing message: 36 (size=9)Producer got message:  21
#
# Consumer storing message: 63 (size=9)
# Consumer storing message: 16 (size=8)
# Consumer storing message: 35 (size=7)
# Consumer storing message: 36 (size=6)
# Consumer storing message: 60 (size=5)
# Consumer storing message: 84 (size=4)
# Consumer storing message: 32 (size=3)
# Consumer storing message: 58 (size=2)
# Consumer storing message: 64 (size=1)
# Consumer storing message: 4 (size=0)
# Producer got message:  49
# Producer got message:  7
# Producer got message:  30
# Producer got message:  82
# Producer got message:  28
# Producer got message:  36
# Producer got message:  30
# Producer got message:  45
# Producer got message:  56
# Producer got message:  20
# Consumer storing message: 21 (size=9)
# Consumer storing message: 49 (size=8)
# Consumer storing message: 7 (size=7)
# Consumer storing message: 30 (size=6)
# Consumer storing message: 82 (size=5)
# Consumer storing message: 28 (size=4)
# Consumer storing message: 36 (size=3)
# Consumer storing message: 30 (size=2)
# Consumer storing message: 45 (size=1)
# Consumer storing message: 56 (size=0)
# Producer got message:  47
# Producer got message:  39
# Producer got message:  39
# Producer got message:  24
# Producer got message:  30
# Producer got message:  40
# Producer got message:  38
# Producer got message:  17
# Producer got message:  5
# Producer got message:  1
# Consumer storing message: 20 (size=9)
# Consumer storing message: 47 (size=8)
# Consumer storing message: 39 (size=7)
# Consumer storing message: 39 (size=6)
# Consumer storing message: 24 (size=5)
# Consumer storing message: 30 (size=4)
# Consumer storing message: 40 (size=3)
# Consumer storing message: 38 (size=2)
# Consumer storing message: 17 (size=1)
# Consumer storing message: 5 (size=0)
# Producer got message:  32
# Producer got message:  82
# Producer got message:  34
# Producer got message:  96
# Producer got message:  71
# Producer got message:  97
# Producer got message:  31
# Producer got message:  59
# Producer got message:  44
# Producer got message:  82
# Consumer storing message: 1 (size=9)
# Consumer storing message: 32 (size=8)
# Consumer storing message: 82 (size=7)
# Consumer storing message: 34 (size=6)
# Consumer storing message: 96 (size=5)
# Consumer storing message: 71 (size=4)
# Consumer storing message: 97 (size=3)
# Consumer storing message: 31 (size=2)
# Consumer storing message: 59 (size=1)
# Consumer storing message: 44 (size=0)
# Producer got message:  34
# Producer got message:  50
# Producer got message:  25
# Producer got message:  98
# Producer got message:  66
# Producer got message:  91
# Producer got message:  70
# Producer got message:  83
# Producer got message:  24
# Producer got message:  50
# Consumer storing message: 82 (size=9)
# Consumer storing message: 34 (size=8)
# Consumer storing message: 50 (size=7)
# Consumer storing message: 25 (size=6)
# Consumer storing message: 98 (size=5)
# Consumer storing message: 66 (size=4)
# Consumer storing message: 91 (size=3)
# Consumer storing message: 70 (size=2)
# Consumer storing message: 83 (size=1)
# Consumer storing message: 24 (size=0)
# Producer got message:  73
# Producer got message:  40
# Producer got message:  11
# Producer got message:  73
# Producer got message:  96
# Producer got message:  50
# Producer got message:  14
# Producer got message:  68
# Producer got message:  94
# Producer got message:  33
# Consumer storing message: 50 (size=9)
# Consumer storing message: 73 (size=8)
# Consumer storing message: 40 (size=7)
# Consumer storing message: 11 (size=6)
# Consumer storing message: 73 (size=5)
# Consumer storing message: 96 (size=4)
# Consumer storing message: 50 (size=3)
# Consumer storing message: 14 (size=2)
# Consumer storing message: 68 (size=1)
# Consumer storing message: 94 (size=0)
# Producer got message:  63
# Producer got message:  74
# Producer got message:  72
# Producer got message:  38
# Producer got message:  9
# Producer got message:  34
# Producer got message:  78
# Producer got message:  43
# Producer got message:  57
# Producer got message:  68
# Consumer storing message: 33 (size=9)
# Consumer storing message: 63 (size=8)
# Consumer storing message: 74 (size=7)
# Consumer storing message: 72 (size=6)
# Consumer storing message: 38 (size=5)
# Consumer storing message: 9 (size=4)
# Consumer storing message: 34 (size=3)
# Consumer storing message: 78 (size=2)
# Consumer storing message: 43 (size=1)
# Consumer storing message: 57 (size=0)
# Producer got message:  32
# Producer got message:  94
# Producer got message:  90
# Producer got message:  51
# Producer got message:  7
# Producer got message:  94
# Producer got message:  62
# Producer got message:  12
# Producer got message:  50
# Producer got message:  71
# Consumer storing message: 68 (size=9)
# Consumer storing message: 32 (size=8)
# Consumer storing message: 94 (size=7)
# Consumer storing message: 90 (size=6)
# Consumer storing message: 51 (size=5)
# Consumer storing message: 7 (size=4)
# Consumer storing message: 94 (size=3)
# Consumer storing message: 62 (size=2)
# Consumer storing message: 12 (size=1)
# Consumer storing message: 50 (size=0)
# Producer got message:  59
# Producer got message:  33
# Producer got message:  94
# Producer got message:  27
# Producer got message:  21
# Producer got message:  43
# Producer got message:  43
# Producer got message:  85
# Producer got message:  54
# Producer got message:  16
# Consumer storing message: 71 (size=9)
# Consumer storing message: 59 (size=8)
# Consumer storing message: 33 (size=7)
# Consumer storing message: 94 (size=6)
# Consumer storing message: 27 (size=5)
# Consumer storing message: 21 (size=4)
# Consumer storing message: 43 (size=3)
# Consumer storing message: 43 (size=2)
# Consumer storing message: 85 (size=1)
# Consumer storing message: 54 (size=0)
# Producer got message:  8
# Producer got message:  87
# Producer got message:  83
# Producer got message:  79
# Producer got message:  2
# Producer got message:  99
# Producer got message:  79
# Producer got message:  54
# Producer got message:  54
# Producer got message:  26
# Consumer storing message: 16 (size=9)
# Consumer storing message: 8 (size=8)
# Consumer storing message: 87 (size=7)
# Consumer storing message: 83 (size=6)
# Consumer storing message: 79 (size=5)
# Consumer storing message: 2 (size=4)
# Consumer storing message: 99 (size=3)
# Consumer storing message: 79 (size=2)
# Consumer storing message: 54 (size=1)
# Consumer storing message: 54 (size=0)
# Producer got message:  35
# Producer got message:  36
# Producer got message:  82
# Producer got message:  47
# Producer got message:  23
# Producer got message:  25
# Producer got message:  36
# Producer got message:  31
# Producer got message:  54
# Producer got message:  85
# Consumer storing message: 26 (size=9)
# Consumer storing message: 35 (size=8)
# Consumer storing message: 36 (size=7)
# Consumer storing message: 82 (size=6)
# Consumer storing message: 47 (size=5)
# Consumer storing message: 23 (size=4)
# Consumer storing message: 25 (size=3)
# Consumer storing message: 36 (size=2)
# Consumer storing message: 31 (size=1)
# Consumer storing message: 54 (size=0)
# Producer got message:  49
# Producer got message:  100
# Producer got message:  93
# Producer got message:  33
# Producer got message:  53
# Producer got message:  4
# Producer got message:  48
# Producer got message:  93
# Producer got message:  99
# Producer got message:  9
# Consumer storing message: 85 (size=9)
# Consumer storing message: 49 (size=8)
# Consumer storing message: 100 (size=7)
# Consumer storing message: 93 (size=6)
# Consumer storing message: 33 (size=5)
# Consumer storing message: 53 (size=4)
# Consumer storing message: 4 (size=3)
# Consumer storing message: 48 (size=2)
# Consumer storing message: 93 (size=1)
# Consumer storing message: 99 (size=0)
# Producer got message:  93
# Producer got message:  87
# Producer got message:  84
# Producer got message:  45
# Producer got message:  60
# Producer got message:  53
# Producer got message:  58
# Producer got message:  95
# Producer got message:  12
# Producer got message:  97
# Consumer storing message: 9 (size=9)
# Consumer storing message: 93 (size=8)
# Consumer storing message: 87 (size=7)
# Consumer storing message: 84 (size=6)
# Consumer storing message: 45 (size=5)
# Consumer storing message: 60 (size=4)
# Consumer storing message: 53 (size=3)
# Consumer storing message: 58 (size=2)
# Consumer storing message: 95 (size=1)
# Consumer storing message: 12 (size=0)
# Producer got message:  62
# Producer got message:  84
# Producer got message:  20
# Producer got message:  21
# Producer got message:  74
# Producer got message:  43
# Producer got message:  2
# Producer got message:  24
# Consumer storing message: 97 (size=8)
# Consumer storing message: 62 (size=7)
# Consumer storing message: 84 (size=6)
# Consumer storing message: 20 (size=5)
# Consumer storing message: 21 (size=4)
# Consumer storing message: 74 (size=3)
# Consumer storing message: 43 (size=2)
# Consumer storing message: 2 (size=1)
# Consumer storing message: 24 (size=0)

# %% [markdown]
# ## Actor Model

# %%
import sys
# !{sys.executable} -m pip install thespian
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting thespian
#   Downloading thespian-3.10.1.zip (493 kB)
#      |████████████████████████████████| 493 kB 32 kB/s  eta 0:00:01
# Building wheels for collected packages: thespian
#   Building wheel for thespian (setup.py) ... done
#   Created wheel for thespian: filename=thespian-3.10.1-py3-none-any.whl size=266580 sha256=9d1467953480826472a4a4bfd044a085852b527f9c6435b371a7c21d10e1cb73
#   Stored in directory: /home/anmol/.cache/pip/wheels/d1/0b/d6/3c7a8ef29276b6bd1c8cb51b74315b58a078fe6b9be92a9d22
# Successfully built thespian
# Installing collected packages: thespian
# Successfully installed thespian-3.10.1

# %%
from thespian.actors import Actor
from thespian.actors import ActorSystem

class Hello(Actor):
    def receiveMessage(self, message, sender):
        if message.startswith("Hello! My name is"):
            your_name = self.createActor(YourName)
            your_name_msg = (sender, "Hello, ", message)
            self.send(your_name, your_name_msg)

class YourName(Actor):
    def receiveMessage(self, message, sender):
        if isinstance(message, tuple):
            orig_sender, pre_hello, orig_message = message
            orig_name = orig_message.lstrip("Hello! My name is ")
            self.send(orig_sender, pre_hello + orig_name)

ActorSystem()
hello = ActorSystem().createActor(Hello)
ActorSystem().ask(hello, "Hello! My name is Anmol")
# Out:
# 'Hello, Anmol'

# %%
##satyam's code
#https://paste.ofcode.org/PwX4c3mSAGjBhZQxs6Tq3x

import asyncio
import time
import os
from concurrent.futures import ThreadPoolExecutor


def blocking_code():
    time.sleep(3)
    print("task completed")
    return time.time_ns()


async def main():
    loop = asyncio.get_running_loop()
    with ThreadPoolExecutor(max_workers=os.cpu_count()) as exe:
        results = await asyncio.gather(*[loop.run_in_executor(exe, blocking_code) for i in range(10)])
        print(results)


loop = asyncio.get_event_loop()
loop.run_until_complete(asyncio.gather(main()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-0d709d63050d> in <module>
#      21
#      22 loop = asyncio.get_event_loop()
# ---> 23 loop.run_until_complete(asyncio.gather(main()))
#
# ~/.local/lib/python3.6/site-packages/nest_asyncio.py in run_until_complete(self, future)
#      93                 raise RuntimeError(
#      94                     'Event loop stopped before Future completed.')
# ---> 95             return f.result()
#      96         finally:
#      97             events._set_running_loop(old_running_loop)
#
# /usr/lib/python3.6/asyncio/tasks.py in _step(***failed resolving arguments***)
#     178                 # We use the `send` method directly, because coroutines
#     179                 # don't have `__iter__` and `__next__` methods.
# --> 180                 result = coro.send(None)
#     181             else:
#     182                 result = coro.throw(exc)
#
# <ipython-input-59-0d709d63050d> in main()
#      14
#      15 async def main():
# ---> 16     loop = asyncio.get_running_loop()
#      17     with ThreadPoolExecutor(max_workers=os.cpu_count()) as exe:
#      18         results = await asyncio.gather(*[loop.run_in_executor(exe, blocking_code) for i in range(10)])
#
# AttributeError: module 'asyncio' has no attribute 'get_running_loop'
